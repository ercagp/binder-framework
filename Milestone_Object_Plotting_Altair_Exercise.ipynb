# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as mt
import os
from pathlib import Path
import altair as alt

# %%
Pth = '//Users//ercagpince//Downloads//Pandas_Milestone'
Init_L = os.listdir(Pth)
FileList = "Final_DF.csv"
Complete_File = Path(Pth, FileList)
Data = pd.read_csv(Complete_File)

# %%
chart = alt.Chart(Data)

# %%
chart = alt.Chart(Data).mark_point().encode(
    x = 'Average total savings',
    y = 'Total jobs created').interactive()
chart
# Out:
# alt.Chart(...)

# %%
print(chart.to_json())
# Out:
# {
#   "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json",
#   "config": {
#     "view": {
#       "continuousHeight": 300,
#       "continuousWidth": 400
#     }
#   },
#   "data": {
#     "name": "data-e65aeb67f535c0b9d8744990ce9919b2"
#   },
#   "datasets": {
#     "data-e65aeb67f535c0b9d8744990ce9919b2": [
#       {
#         "Average total savings": 37214.024,
#         "NTA": "SoHo-TriBeCa-Civic Center-Little Italy",
#         "Total jobs created": 0.0,
#         "Unnamed: 0": 0
#       },
#       {
#         "Average total savings": 469890.7966666666,
#         "NTA": "Battery Park City-Lower Manhattan",
#         "Total jobs created": 0.0,
#         "Unnamed: 0": 0
#       },
#       {
#         "Average total savings": 14316.976875000002,
#         "NTA": "Sunset Park West",
#         "Total jobs created": 0.0,
#         "Unnamed: 0": 0
#       },
#       {
#         "Average total savings": 23931.398933333337,
# ...

# %%
chart.save('chart.html')

# %%
New_File = "Value_of_Energy_Cost_Savings_Program_Savings_for_Businesses_-_FY2020.csv"

# %%
C_New_File = Path(Pth, New_File)
New_Data = pd.read_csv(C_New_File)

# %%
chart_2 = alt.Chart(New_Data)

# %%
from IPython.display import display, HTML
print ("New Dataframe :")
display(New_Data)
# Out:
# New Dataframe :
#                                  Company Name    company contact  \
# 0                              1 State Street      David Neiburg
# 1                              100 Church LLC  Edward A. Carroll
# 2                        100 Wall Investments       Jerry Branam
# 3                 1-10 Bush Terminal Owner LP     Andrew Kimball
# 4    120 Broadway Acquisitions JV, LLC (Ldmk)        Carl Letich
# ..                                        ...                ...
# 445                         WONTON FOOD, INC.         DONALD LAU
# 446                                Wood Works       Gordon Brawm
# 447           WorldWide Plumbing Supply, Inc.    Surie Lefkowitz
# 448                         WUD Furniture LLC     Keren Springer
# 449                       Wurtec Incorporated          Bill Popp
#
#                  company email company phone                Address  \
# 0       eskoblo@energyspec.com    7186779077          1114 Avenue J
# ...

# %%
New_Data.columns
# Out:
# Index(['Company Name', 'company contact', 'company email', 'company phone',
#        'Address', 'City', 'State', 'Postcode', 'Industry', 'Industry descr',
#        'Company Type', 'Current fulltime', 'Job created', 'Job retain',
#        'Effective Date', 'Total Savings',
#        'Savings from beginning receiving benefits', 'Borough', 'Latitude',
#        'Longitude', 'Community Board', 'Council District', 'Census Tract',
#        'BIN', 'BBL', 'NTA'],
#       dtype='object')

# %%
chart_2 = alt.Chart(New_Data)

# %%
chart_2 = alt.Chart(New_Data).mark_point().encode(
    x = 'Savings from beginning receiving benefits',
    y = 'Job created').interactive()
chart_2
# Out:
# alt.Chart(...)

# %%
chart_3 = alt.Chart(New_Data).mark_bar().encode(
alt.X("Job created:Q", bin = True),  
y = 'count()').interactive()

chart_3
# Out:
# alt.Chart(...)

# %%
chart_3.save('chart_3.html')
